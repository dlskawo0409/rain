# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split 
import sklearn.metrics as mt
import seaborn as sns
import warnings

from sklearn.ensemble import RandomForestClassifier
warnings.filterwarnings('ignore')

# %%
weather_df = pd.read_csv('./data/pre_labeled_weather.csv',index_col = 0)

# %%
weather_df = pd.read_csv('./data/MiceImputed_weather.csv',index_col = 0)

# %%
weather_df
# Out:
#         location    Date  MinTemp  MaxTemp  Rainfall  WindGustSpeed  \
# 0           45.0     0.0     12.6     23.2       0.5            6.4
# 1           45.0     1.0     10.6     24.1       0.0            6.5
# 2           45.0     2.0     14.2     25.1       0.0            7.0
# 3           45.0     3.0     12.1     21.1       0.0            6.1
# 4           45.0     4.0     11.9     15.4       0.0            6.5
# ...          ...     ...      ...      ...       ...            ...
# 343701      17.0  3647.0      9.8     20.3       0.0            4.8
# 343702      17.0  3648.0      7.9     21.5       0.0            5.4
# 343703      17.0  3649.0      8.3     19.9       0.0            3.6
# 343704      17.0  3650.0      8.2     22.7       0.0            4.1
# 343705      17.0  3651.0      9.5     23.7       0.0            3.9
#
#         WindGustDir   Sunshine  Evaporation  TodayRain  ...  Cloud9am  \
# 0               7.0  17.627755     4.696022        0.0  ...       0.0
# ...

# %%
# 'n_estimators':[100,200, 300, 400],
#     'max_depth' : [6, 8, 10, 12, 16, 20], 
#     'min_samples_leaf' : [8, 12, 18 ],
#     'min_samples_split' : [8, 16, 20]

# %%
Y = weather_df['TomorrowRain']
weather_df.drop(['TomorrowRain'], axis = 1, inplace = True)
X = weather_df

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, 
                                                    test_size=0.2 , random_state= 156, stratify=Y)

# %%
import sklearn.metrics as mt
def get_clf_eval(y_test, pred=None):
    confusion = mt.confusion_matrix( y_test, pred)
    accuracy = mt.accuracy_score(y_test , pred)
    precision = mt.precision_score(y_test , pred)
    recall = mt.recall_score(y_test , pred)
    f1 = mt.f1_score(y_test,pred)

    print('오차 행렬:')
    print(confusion)
    
    print('\n정확도: {0:.4f} \n정밀도: {1:.4f} \n재현율: {2:.4f} \n    F1: {3:.4f}'.format(accuracy, precision, recall, f1))

# %%
rf_clf = RandomForestClassifier(random_state=0)
rf_clf.fit(X_train , y_train)
pred = rf_clf.predict(X_test)
get_clf_eval(y_test, pred)
# Out:
# 오차 행렬:
# [[53426  1276]
#  [ 9487  4553]]
#
# 정확도: 0.8434
# 정밀도: 0.7811
# 재현율: 0.3243
#     F1: 0.4583

# %%
rf_clf = RandomForestClassifier(random_state=0, max_depth = 10)
rf_clf.fit(X_train , y_train)
pred = rf_clf.predict(X_test)
get_clf_eval(y_test, pred)
# Out:
# 오차 행렬:
# [[53559  1143]
#  [11183  2857]]
#
# 정확도: 0.8207
# 정밀도: 0.7143
# 재현율: 0.2035
#     F1: 0.3167

# %%
rf_clf = RandomForestClassifier(random_state=10, max_depth = 20)
rf_clf.fit(X_train , y_train)
pred = rf_clf.predict(bX_test)
get_clf_eval(y_test, pred)
# Out:
# 오차 행렬:
# [[53388  1314]
#  [ 9735  4305]]
#
# 정확도: 0.8393
# 정밀도: 0.7662
# 재현율: 0.3066
#     F1: 0.4380

# %%
rf_clf = RandomForestClassifier(random_state=10, max_depth = 20,n_estimators=50)
rf_clf.fit(X_train , y_train)
pred = rf_clf.predict(X_test)
get_clf_eval(y_test, pred)
# Out:
# 오차 행렬:
# [[53314  1388]
#  [ 9738  4302]]
#
# 정확도: 0.8381
# 정밀도: 0.7561
# 재현율: 0.3064
#     F1: 0.4361

# %%
rf_clf = RandomForestClassifier(random_state=10, max_depth = 20,n_estimators=200)
rf_clf.fit(X_train , y_train)
pred = rf_clf.predict(X_test)
get_clf_eval(y_test, pred)
# Out:
# 오차 행렬:
# [[53464  1238]
#  [ 9735  4305]]
#
# 정확도: 0.8404
# 정밀도: 0.7767
# 재현율: 0.3066
#     F1: 0.4397

# %%
rf_clf = RandomForestClassifier(random_state=10, max_depth = 20,n_estimators=400)
rf_clf.fit(X_train , y_train)
pred = rf_clf.predict(X_test)
get_clf_eval(y_test, pred)
# Out:
# 오차 행렬:
# [[53466  1236]
#  [ 9739  4301]]
#
# 정확도: 0.8403
# 정밀도: 0.7768
# 재현율: 0.3063
#     F1: 0.4394

# %%
rf_clf = RandomForestClassifier(random_state=10, max_depth = 20,n_estimators=200,criterion="entropy")
rf_clf.fit(X_train , y_train)
pred = rf_clf.predict(X_test)
get_clf_eval(y_test, pred)
# Out:
# 오차 행렬:
# [[53460  1242]
#  [ 9745  4295]]
#
# 정확도: 0.8402
# 정밀도: 0.7757
# 재현율: 0.3059
#     F1: 0.4388

# %%
rf_clf = RandomForestClassifier(random_state=10, max_depth = 20,n_estimators=200,criterion="log_loss")
rf_clf.fit(X_train , y_train)
pred = rf_clf.predict(X_test)
get_clf_eval(y_test, pred)
# Out:
# 오차 행렬:
# [[53460  1242]
#  [ 9745  4295]]
#
# 정확도: 0.8402
# 정밀도: 0.7757
# 재현율: 0.3059
#     F1: 0.4388

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

from lightgbm import LGBMClassifier
import warnings
warnings.filterwarnings("ignore")
# Multiple Imputation by Chained Equations
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
# %matplotlib inline

# %%
weather_df=pd.read_csv("real_weather.csv", encoding = 'cp949')
weather_df
# Out:
#        location        Date  MinTemp  MaxTemp  Rainfall  WindGustSpeed  \
# 0            속초  2012-05-05     12.6     23.2       0.5            6.4
# 1            속초  2012-05-06     10.6     24.1       NaN            6.5
# 2            속초  2012-05-07     14.2     25.1       NaN            7.0
# 3            속초  2012-05-08     12.1     21.1       NaN            6.1
# 4            속초  2012-05-09     11.9     15.4       NaN            6.5
# ...         ...         ...      ...      ...       ...            ...
# 343701       남해  2022-05-01      9.8     20.3       NaN            4.8
# 343702       남해  2022-05-02      7.9     21.5       NaN            5.4
# 343703       남해  2022-05-03      8.3     19.9       NaN            3.6
# 343704       남해  2022-05-04      8.2     22.7       NaN            4.1
# 343705       남해  2022-05-05      9.5     23.7       NaN            3.9
#
#        WindGustDir  Sunshine  Evaporation  TodayRain  ...  Cloud9am  \
# 0               NW       NaN          NaN          0  ...       0.0
# 1              WSW       NaN          NaN          0  ...       3.0
# 2               NW       NaN          NaN          0  ...       0.0
# 3               NW       NaN          NaN          0  ...       9.0
# 4               NW       NaN          NaN          0  ...       8.0
# ...            ...       ...          ...        ...  ...       ...
# 343701         WNW       NaN          NaN          0  ...       4.0
# 343702         WNW       NaN          NaN          0  ...       0.0
# 343703         SSW       NaN          NaN          0  ...       2.0
# 343704         SSW       NaN          NaN          0  ...       0.0
# 343705         SSW       NaN          NaN          0  ...       0.0
#
#         Humidity9am WindSpeed9am  Temp9am  Pressure3pm  WindDir3pm  Cloud3pm  \
# 0              66.0          1.6     18.3        998.7          SE       6.0
# 1              30.0          5.1     18.6       1000.8           E       2.0
# 2              26.0          3.1     22.2       1002.8           E       0.0
# 3              66.0          0.8     17.0       1005.5         ESE       3.0
# 4              90.0          3.8     14.7       1013.2         NNW       9.0
# ...             ...          ...      ...          ...         ...       ...
# 343701         48.0          1.2     14.4       1006.8           S       1.0
# 343702         50.0          1.7     15.9       1006.5         WSW       7.0
# 343703         66.0          1.2     13.0       1014.3           S       0.0
# 343704         59.0          1.0     15.5       1014.0         SSW       0.0
# 343705         70.0          1.2     17.3       1013.6          SW       0.0
#
#         Humidity3pm WindSpeed3pm  Temp3pm
# 0              51.0          4.2     19.3
# 1              35.0          2.7     20.5
# 2              31.0          2.1     22.9
# 3              70.0          2.8     18.3
# 4              89.0          4.6     13.9
# ...             ...          ...      ...
# 343701         35.0          2.4     19.5
# 343702         42.0          2.2     20.6
# 343703         37.0          2.7     18.9
# 343704         39.0          2.6     21.3
# 343705         44.0          2.6     22.6
#
# [343706 rows x 23 columns]

# %%
missing_values=weather_df.isnull().sum() # missing values

percent_missing = weather_df.isnull().sum()/weather_df.shape[0]*100 # missing value %

value = {
    'missing_values ':missing_values,
    'percent_missing %':percent_missing 
}
frame=pd.DataFrame(value)
frame
# Out:
#                missing_values   percent_missing %
# location                     0           0.000000
# Date                         0           0.000000
# MinTemp                     34           0.009892
# MaxTemp                     27           0.007856
# Rainfall                217587          63.306140
# WindGustSpeed              181           0.052661
# WindGustDir                168           0.048879
# Sunshine                194241          56.513706
# Evaporation             222948          64.865903
# TodayRain                    0           0.000000
# TomorrowRain                 0           0.000000
# Pressure9am                282           0.082047
# WindDir9am                 725           0.210936
# Cloud9am                145659          42.378952
# Humidity9am                334           0.097176
# WindSpeed9am               238           0.069245
# Temp9am                     46           0.013384
# Pressure3pm                242           0.070409
# WindDir3pm                 701           0.203953
# Cloud3pm                145707          42.392917
# Humidity3pm                204           0.059353
# WindSpeed3pm               239           0.069536
# Temp3pm                     49           0.014256

# %%
total = weather_df.isnull().sum().sort_values(ascending=False)
percent = (weather_df.isnull().sum()/weather_df.isnull().count()).sort_values(ascending=False)
missing = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing.head(4)
# Out:
#               Total   Percent
# Evaporation  222948  0.648659
# Rainfall     217587  0.633061
# Sunshine     194241  0.565137
# Cloud3pm     145707  0.423929

# %%
 weather_df['Rainfall'].fillna(0, inplace=True)

# %%
weather_df.select_dtypes(include=['object']).columns
# Out:
# Index(['location', 'Date', 'WindGustDir', 'WindDir9am', 'WindDir3pm'], dtype='object')

# %%
lencoders = {}
for col in weather_df.select_dtypes(include=['object']).columns:
    lencoders[col] = LabelEncoder()
    weather_df[col] = lencoders[col].fit_transform(weather_df[col])

# %%
MiceImputed = weather_df.copy(deep=True) 
mice_imputer = IterativeImputer()
MiceImputed.iloc[:, :] = mice_imputer.fit_transform(weather_df)

# %%
MiceImputed.to_csv("MiceImputed_weather")

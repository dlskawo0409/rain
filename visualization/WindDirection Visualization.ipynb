# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from math import pi
from matplotlib.path import Path
from matplotlib.spines import Spine
from matplotlib.transforms import Affine2D

pd.set_option('display.max_rows',98)

# %%
df=pd.read_csv("real_real_weather.csv",encoding="cp949")

# %%
labels=df['WindGustDir'].unique()
labels=labels[:16]
label=[]
for i in range(len(labels)):
    label.append(labels[i])
label
label=[*label,label[0]]

# %%
label_loc=np.linspace(start=0,stop=2*np.pi,num=len(label))
plt.figure(figsize=(8,8))
ax=plt.subplot(polar=True)
plt.xticks(label_loc,labels=label,fontsize=13)
ax.plot(label_loc,val,label='dir',linestyle='dashed',color='lightcoral')
ax.fill(label_loc,val,color='lightcoral',alpha=0.3)
ax.legend()
plt.show()

# %%
list=df['WindDir9am'].value_counts()
val=[]
for i in range(len(list)):
    val.append(list[i])
val=[*val,val[0]]
labels=df['WindDir9am'].unique()
labels=labels[:16]
label=[]
for i in range(len(labels)):
    label.append(labels[i])
label
label=[*label,label[0]]
label_loc=np.linspace(start=0,stop=2*np.pi,num=len(label))
plt.figure(figsize=(8,8))
ax=plt.subplot(polar=True)
plt.xticks(label_loc,labels=label,fontsize=13)
ax.plot(label_loc,val,label='dir',linestyle='dashed',color='lightcoral')
ax.fill(label_loc,val,color='lightcoral',alpha=0.3)
ax.legend()
plt.show()

# %%
list=df['WindDir3pm'].value_counts()
val=[]
for i in range(len(list)):
    val.append(list[i])
val=[*val,val[0]]
labels=df['WindDir3pm'].unique()
labels=labels[:16]
label=[]
for i in range(len(labels)):
    label.append(labels[i])
label
label=[*label,label[0]]
label_loc=np.linspace(start=0,stop=2*np.pi,num=len(label))
plt.figure(figsize=(8,8))
ax=plt.subplot(polar=True)
plt.xticks(label_loc,labels=label,fontsize=13)
ax.plot(label_loc,val,label='dir',linestyle='dashed',color='lightcoral')
ax.fill(label_loc,val,color='lightcoral',alpha=0.3)
ax.legend()
plt.show()
